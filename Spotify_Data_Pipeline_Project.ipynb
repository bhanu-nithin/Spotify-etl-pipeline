# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id ='d45060c18c2547d0861aad7eb25e739e',client_secret ='96b7e6e9bd4a41008b652548ed721e69')

# %%
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
playlist_link = 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF'

# %%
playlist_uri = playlist_link.split('/')[-1]

# %%
playlist_uri
# Out:
# '37i9dQZEVXbMDoHDwVN2tF'

# %%
data = sp.playlist_tracks(playlist_uri)

# %%
data['items'][0]['track']['album']['id']
data['items'][0]['track']['album']['name']
data['items'][0]['track']['album']['release_date']
data['items'][0]['track']['album']['total_tracks']
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_external_urls= row['track']['album']['external_urls']['spotify']
    album_elements = {'album_id': album_id,'album_name':album_name,'album_release_date': album_release_date,
                      'album_total_tracks':album_total_tracks,'album_external_urls':album_external_urls}
    album_list.append(album_elements)

# %%
album_list
# Out:
# [{'album_id': '15XcLhiVMlSOipUddTNDnr',
#   'album_name': 'MUSE',
#   'album_release_date': '2024-07-19',
#   'album_total_tracks': 7,
#   'album_external_urls': 'https://open.spotify.com/album/15XcLhiVMlSOipUddTNDnr'},
#  {'album_id': '7aJuG4TFXa2hmE4z1yxc3n',
#   'album_name': 'HIT ME HARD AND SOFT',
#   'album_release_date': '2024-05-17',
#   'album_total_tracks': 10,
#   'album_external_urls': 'https://open.spotify.com/album/7aJuG4TFXa2hmE4z1yxc3n'},
#  {'album_id': '5quMTd5zeI9yW5UDua8wS4',
#   'album_name': 'Espresso',
#   'album_release_date': '2024-04-12',
#   'album_total_tracks': 1,
#   'album_external_urls': 'https://open.spotify.com/album/5quMTd5zeI9yW5UDua8wS4'},
#  {'album_id': '5bBaoign62r1i7OV8w7mi9',
#   'album_name': 'Please Please Please',
#   'album_release_date': '2024-06-06',
#   'album_total_tracks': 2,
#   'album_external_urls': 'https://open.spotify.com/album/5bBaoign62r1i7OV8w7mi9'},
#  {'album_id': '5ylbxH7EqpsmHZCRuiYewS',
# ...

# %%
data['items'][0]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1oSPZhvZMIrWW5I41kPkkY'},
#   'href': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY',
#   'id': '1oSPZhvZMIrWW5I41kPkkY',
#   'name': 'Jimin',
#   'type': 'artist',
#   'uri': 'spotify:artist:1oSPZhvZMIrWW5I41kPkkY'}]

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict ={'artist_id':artist['id'],'artist_name': artist['name'],'external_url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1oSPZhvZMIrWW5I41kPkkY',
#   'artist_name': 'Jimin',
#   'external_url': 'https://api.spotify.com/v1/artists/1oSPZhvZMIrWW5I41kPkkY'},
#  {'artist_id': '6qqNVTkY8uBg9cP3Jd7DAH',
#   'artist_name': 'Billie Eilish',
#   'external_url': 'https://api.spotify.com/v1/artists/6qqNVTkY8uBg9cP3Jd7DAH'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '74KM79TiuVKeVCqs8QtB0B',
#   'artist_name': 'Sabrina Carpenter',
#   'external_url': 'https://api.spotify.com/v1/artists/74KM79TiuVKeVCqs8QtB0B'},
#  {'artist_id': '790FomKkXshlbRYZFtlgla',
#   'artist_name': 'KAROL G',
#   'external_url': 'https://api.spotify.com/v1/artists/790FomKkXshlbRYZFtlgla'},
#  {'artist_id': '7GlBOeep6PqTfFi59PTUUN',
#   'artist_name': 'Chappell Roan',
#   'external_url': 'https://api.spotify.com/v1/artists/7GlBOeep6PqTfFi59PTUUN'},
# ...

# %%
data
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbMDoHDwVN2tF/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-08-12T09:06:10Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#     'href': 'https://api.spotify.com/v1/users/',
#     'id': '',
#     'type': 'user',
#     'uri': 'spotify:user:'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/02687a01e9ec00f4e947f39e910c7e0c6fa83e10?cid=d45060c18c2547d0861aad7eb25e739e',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
# ...

# %%
data['items']
# Out:
# [{'added_at': '2024-08-12T09:06:10Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': 'https://p.scdn.co/mp3-preview/02687a01e9ec00f4e947f39e910c7e0c6fa83e10?cid=d45060c18c2547d0861aad7eb25e739e',
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2024-08-12T09:06:10Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': 'https://p.scdn.co/mp3-preview/02687a01e9ec00f4e947f39e910c7e0c6fa83e10?cid=d45060c18c2547d0861aad7eb25e739e',
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
# ...

# %%
data['items'][0]['track']['id']
data['items'][0]['track']['name']
data['items'][0]['track']['duration_ms']
data['items'][0]['track']['external_urls']['spotify']
data['items'][0]['track']['popularity']
data['items'][0]['added_at']
# Out:
# '2024-08-12T09:06:10Z'

# %%
song_list=[]
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_external_urls = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added_at = row['added_at']
    album_id =row['track']['album']['id']
    artist_id = row['track']['artists'][0]['id']
    song_element = {'song_id':song_id, 'song_name':song_name,'song_duration':song_duration,'song_external_urls':song_external_urls,
                   'song_popularity':song_popularity,'song_added_at':song_added_at,'album_id':album_id,'artist_id':artist_id}
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                    album_name album_release_date  \
# 0  15XcLhiVMlSOipUddTNDnr                          MUSE         2024-07-19
# 1  7aJuG4TFXa2hmE4z1yxc3n          HIT ME HARD AND SOFT         2024-05-17
# 2  5quMTd5zeI9yW5UDua8wS4                      Espresso         2024-04-12
# 3  5bBaoign62r1i7OV8w7mi9          Please Please Please         2024-06-06
# 4  5ylbxH7EqpsmHZCRuiYewS  Si Antes Te Hubiera Conocido         2024-06-21
#
#    album_total_tracks                                album_external_urls
# 0                   7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 1                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2                   1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 3                   2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 4                   1  https://open.spotify.com/album/5ylbxH7EqpsmHZC...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   album_id             50 non-null     object
#  1   album_name           50 non-null     object
#  2   album_release_date   50 non-null     object
#  3   album_total_tracks   50 non-null     int64
#  4   album_external_urls  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   album_id             46 non-null     object
#  1   album_name           46 non-null     object
#  2   album_release_date   46 non-null     object
#  3   album_total_tracks   46 non-null     int64
#  4   album_external_urls  46 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df
# Out:
#                  artist_id        artist_name  \
# 0   1oSPZhvZMIrWW5I41kPkkY              Jimin
# 1   6qqNVTkY8uBg9cP3Jd7DAH      Billie Eilish
# 2   74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 3   74KM79TiuVKeVCqs8QtB0B  Sabrina Carpenter
# 4   790FomKkXshlbRYZFtlgla            KAROL G
# ..                     ...                ...
# 61  06HL4z0CvFAxyc27GXpf02       Taylor Swift
# 62  246dkjvS1zLTtiykXe5h60        Post Malone
# 63  2uYWxilOVlUdk4oV9DvwqK             Mitski
# 64  22wbnEMDvgVIAGdFeek6ET       Benson Boone
# 65  2RQXRUsr4IW1f3mKyKsy4B         Noah Kahan
#
#                                          external_url
# 0   https://api.spotify.com/v1/artists/1oSPZhvZMIr...
# 1   https://api.spotify.com/v1/artists/6qqNVTkY8uB...
# 2   https://api.spotify.com/v1/artists/74KM79TiuVK...
# 3   https://api.spotify.com/v1/artists/74KM79TiuVK...
# 4   https://api.spotify.com/v1/artists/790FomKkXsh...
# ..                                                ...
# ...

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     66 non-null     object
#  1   artist_name   66 non-null     object
#  2   external_url  66 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     55 non-null     object
#  1   artist_name   55 non-null     object
#  2   external_url  55 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
song_df =pd.DataFrame.from_dict(song_list)

# %%
song_df
# Out:
#                    song_id                                          song_name  \
# 0   7tI8dRuH2Yc6RuoTjxo4dU                                                Who
# 1   6dOtVTDdiauQNBQEDOtlAB                                 BIRDS OF A FEATHER
# 2   2qSkIjg1o9h3YT9RAgYN75                                           Espresso
# 3   5N3hjp1WNayUPZrA8kJmJP                               Please Please Please
# 4   6WatFBLVB0x077xWeoVc2k                       Si Antes Te Hubiera Conocido
# 5   0WbMK4wrZ1wFSty9F7FCgu                                   Good Luck, Babe!
# 6   0OA00aPt3BV10qeMIs3meW                                          Big Dawgs
# 7   2esZG2XFtuoWWA9AfDvSxy                                          Gata Only
# 8   3WOhcATHxK2SLNeP5W3v1v                      Guess featuring Billie Eilish
# 9   3xkHsmpQCBMytMJNiDf3Ii                                   Beautiful Things
# 10  5fZJQrFKWQLb7FpJXZ1g7K                                 A Bar Song (Tipsy)
# ...

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   song_id             50 non-null     object
#  1   song_name           50 non-null     object
#  2   song_duration       50 non-null     int64
#  3   song_external_urls  50 non-null     object
#  4   song_popularity     50 non-null     int64
#  5   song_added_at       50 non-null     object
#  6   album_id            50 non-null     object
#  7   artist_id           50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 55 entries, 0 to 65
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_id     55 non-null     object
#  1   artist_name   55 non-null     object
#  2   external_url  55 non-null     object
# dtypes: object(3)
# memory usage: 1.7+ KB

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   album_id             46 non-null     object
#  1   album_name           46 non-null     object
#  2   album_release_date   46 non-null     object
#  3   album_total_tracks   46 non-null     int64
#  4   album_external_urls  46 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   15XcLhiVMlSOipUddTNDnr                                               MUSE
# 1   7aJuG4TFXa2hmE4z1yxc3n                               HIT ME HARD AND SOFT
# 2   5quMTd5zeI9yW5UDua8wS4                                           Espresso
# 3   5bBaoign62r1i7OV8w7mi9                               Please Please Please
# 4   5ylbxH7EqpsmHZCRuiYewS                       Si Antes Te Hubiera Conocido
# 5   1WAjjRMfZjEXtB0lQrAw6Q                                   Good Luck, Babe!
# 6   6Yw4204wbgmpsGTzjXBhYD                                          Big Dawgs
# 7   6MikZBKCtKfPM4439yzBRz                                        EL COMIENZO
# 8   3ThlxfLSy4bfKzxWqmC7VN                      Guess featuring Billie Eilish
# 9   168CdR21lfn0TTyw1Pkdcm                           Fireworks & Rollerblades
# 10  0DLvFVIfwt3OHdK9kGeEM3             Where I've Been, Isn't Where I'm Going
# ...

# %%
album_df.head()
# Out:
#                  album_id                    album_name album_release_date  \
# 0  15XcLhiVMlSOipUddTNDnr                          MUSE         2024-07-19
# 1  7aJuG4TFXa2hmE4z1yxc3n          HIT ME HARD AND SOFT         2024-05-17
# 2  5quMTd5zeI9yW5UDua8wS4                      Espresso         2024-04-12
# 3  5bBaoign62r1i7OV8w7mi9          Please Please Please         2024-06-06
# 4  5ylbxH7EqpsmHZCRuiYewS  Si Antes Te Hubiera Conocido         2024-06-21
#
#    album_total_tracks                                album_external_urls
# 0                   7  https://open.spotify.com/album/15XcLhiVMlSOipU...
# 1                  10  https://open.spotify.com/album/7aJuG4TFXa2hmE4...
# 2                   1  https://open.spotify.com/album/5quMTd5zeI9yW5U...
# 3                   2  https://open.spotify.com/album/5bBaoign62r1i7O...
# 4                   1  https://open.spotify.com/album/5ylbxH7EqpsmHZC...

# %%
album_df['album_release_date'] = pd.to_datetime(album_df['album_release_date'],errors='coerce')

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   album_id             46 non-null     object
#  1   album_name           46 non-null     object
#  2   album_release_date   45 non-null     datetime64[ns]
#  3   album_total_tracks   46 non-null     int64
#  4   album_external_urls  46 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   song_id             50 non-null     object
#  1   song_name           50 non-null     object
#  2   song_duration       50 non-null     int64
#  3   song_external_urls  50 non-null     object
#  4   song_popularity     50 non-null     int64
#  5   song_added_at       50 non-null     object
#  6   album_id            50 non-null     object
#  7   artist_id           50 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ KB

# %%
song_df['song_added_at'] = pd.to_datetime(song_df['song_added_at'],errors='coerce')

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   song_id             50 non-null     object
#  1   song_name           50 non-null     object
#  2   song_duration       50 non-null     int64
#  3   song_external_urls  50 non-null     object
#  4   song_popularity     50 non-null     int64
#  5   song_added_at       50 non-null     datetime64[ns, UTC]
#  6   album_id            50 non-null     object
#  7   artist_id           50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
